# %% [markdown]
# # 📊 Python Data Analysis Starter
#
# **Goal**: Load a dataset, perform basic exploratory data analysis (EDA), and visualize the results using Pandas and Matplotlib.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Set seed for reproducibility
np.random.seed(42)

# %% [markdown]
# ### 1. Generating Synthetic Data
# Instead of downloading a CSV, we will generate a synthetic dataset representing house prices to practice with.

# %%
# Generate 500 rows of synthetic housing data
n_samples = 500

data = {
    'Square_Feet': np.random.normal(1500, 500, n_samples),
    'Bedrooms': np.random.randint(1, 6, n_samples),
    'Age_Years': np.random.randint(0, 50, n_samples),
}

# Price depends heavily on Square_Feet, slightly on Bedrooms, and decreases with Age
data['Price'] = (data['Square_Feet'] * 150) + (data['Bedrooms'] * 10000) - (data['Age_Years'] * 500) + np.random.normal(0, 10000, n_samples)

df = pd.DataFrame(data)

print("Data generated successfully!")
df.head()
# Out:
# Data generated successfully!
#    Square_Feet  Bedrooms  Age_Years          Price
# 0  1748.357077         2          9  264806.746719
# 1  1430.867849         2         29  231738.445286
# 2  1823.844269         3         24  286899.628344
# 3  2261.514928         3         38  353692.278048
# 4  1382.923313         5         19  247469.291107

# %% [markdown]
# ### 2. Basic Data Exploration
# Let's look at the shape of the data and some summary statistics.

# %%
print(f"Dataset Shape: {df.shape}")
print("\nMissing Values:\n", df.isnull().sum())

# Get summary statistics
df.describe()
# Out:
# Dataset Shape: (500, 4)
#
# Missing Values:
#  Square_Feet    0
# Bedrooms       0
# Age_Years      0
# Price          0
# dtype: int64
#        Square_Feet    Bedrooms  Age_Years          Price
# count   500.000000  500.000000  500.00000     500.000000
# mean   1503.418997    2.966000   24.50400  243712.130593
# std     490.626624    1.422988   14.23655   76113.452571
# min    -120.633670    1.000000    0.00000    7308.002066
# 25%    1149.846298    2.000000   12.00000  189937.305902
# 50%    1506.398573    3.000000   24.50000  244719.230030
# 75%    1818.391627    4.000000   36.25000  295390.504417
# max    3426.365745    5.000000   49.00000  532872.030936

# %% [markdown]
# ### 3. Data Visualization
# Let's create some plots to understand the relationships between variables.

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Plot 1: Histogram of Prices
axes[0].hist(df['Price'], bins=30, color='skyblue', edgecolor='black')
axes[0].set_title('Distribution of House Prices')
axes[0].set_xlabel('Price ($)')
axes[0].set_ylabel('Count')
axes[0].grid(axis='y', alpha=0.75)

# Plot 2: Scatter plot of Square Feet vs Price
axes[1].scatter(df['Square_Feet'], df['Price'], alpha=0.5, color='coral')
axes[1].set_title('Price vs. Square Footage')
axes[1].set_xlabel('Square Feet')
axes[1].set_ylabel('Price ($)')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. Correlation Analysis
# Which feature correlates the most with the Price?

# %%
correlation_matrix = df.corr()

print("Correlation with Price:")
print(correlation_matrix['Price'].sort_values(ascending=False))
# Out:
# Correlation with Price:
# Price          1.000000
# Square_Feet    0.973339
# Bedrooms       0.180452
# Age_Years     -0.093226
# Name: Price, dtype: float64

# %% [markdown]
# ### 🎉 Conclusion
# You have successfully loaded data into a Pandas DataFrame, computed summary statistics, and visualized the relationships using Matplotlib!
