# %% [markdown]
# # 🛣️ Support Vector Machines Workshop
# SVM tries to find the widest possible 'street' (margin) separating two classes.

# %% [markdown]
# ## 1. Problem Overview
# We will classify synthetic blob data to see the margins clearly.

# %% [markdown]
# ## 2. Dataset Exploration

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=100, centers=2, random_state=6)
plt.scatter(X[:,0], X[:,1], c=y, cmap='coolwarm')
plt.show()

# %% [markdown]
# ## 3. Data Preprocessing

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## 6. Scikit-Learn Workflow

# %%
from sklearn.svm import SVC

# Linear Kernel
model = SVC(kernel='linear', C=1.0)
model.fit(X_scaled, y)

# %% [markdown]
# ## 7. Visualization Lab
# Plotting the maximum margin and support vectors.

# %%
ax = plt.gca()
plt.scatter(X_scaled[:,0], X_scaled[:,1], c=y, cmap='coolwarm')

xlim = ax.get_xlim()
ylim = ax.get_ylim()
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = model.decision_function(xy).reshape(XX.shape)

ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5, linestyles=['--', '-', '--'])
ax.scatter(model.support_vectors_[:,0], model.support_vectors_[:,1], s=100, linewidth=1, facecolors='none', edgecolors='k')
plt.title('SVM Margin and Support Vectors')
plt.show()

# %% [markdown]
# ## 8. Hyperparameter Experiments
# The Kernel Trick! Using RBF for non-linear data.

# %%
from sklearn.datasets import make_circles
X_circ, y_circ = make_circles(n_samples=100, factor=0.1, noise=0.1)
rbf_model = SVC(kernel='rbf', C=1.0, gamma='scale')
rbf_model.fit(X_circ, y_circ)
print('RBF Kernel easily handles circular boundaries!')
