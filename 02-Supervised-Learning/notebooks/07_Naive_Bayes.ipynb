# %% [markdown]
# # Naive Bayes
#
# ## 1. Problem Overview
# We will build a probabilistic classifier using Bayes' Theorem.
#
# ## 2. Dataset Exploration
# Loading a text dataset (e.g., SMS Spam Collection).
#
# ## 3. Data Preprocessing
# Converting raw text to Bag of Words (CountVectorizer) or TF-IDF.
#
# ## 4. From Scratch Implementation
# Counting word frequencies and calculating prior/likelihood probabilities manually.
#
# ## 5. NumPy Implementation
# Using array broadcasting to calculate log-probabilities.
#
# ## 6. Scikit-Learn Workflow
# Using `MultinomialNB`.
#
# ## 7. Visualization Lab
# Plotting the most predictive words for each class.
#
# ## 8. Hyperparameter Experiments
# Testing different Laplace smoothing alphas.
#
# ## 9. Failure Cases
# Demonstrating bad probability estimates on correlated features.
#
# ## 10. Real Dataset Case Study
# Full Spam Filter pipeline.
#
# ## 11. Mini Challenges
# Switch from CountVectorizer to TfidfVectorizer and compare accuracy.
#
# ## 12. Solutions
# Reveal solutions here.
#
# ## 13. Key Takeaways
# Naive Bayes is incredibly fast and powerful for text data despite its naive assumption.
#
# ## 14. Further Practice
# Build a sentiment analysis model.

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import make_pipeline

# model = make_pipeline(CountVectorizer(), MultinomialNB())
# model.fit(texts, labels)
