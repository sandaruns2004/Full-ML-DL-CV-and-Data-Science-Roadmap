# %% [markdown]
# # 🏢 Employee Attrition Forecast
# Modeling categorical HR data to predict employee turnover using embeddings and dense layers.

# %%
import torch
import torch.nn as nn
import numpy as np
print('Employee Attrition Notebook Initialized.')
