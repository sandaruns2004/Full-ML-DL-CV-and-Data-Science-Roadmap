# %% [markdown]
# # Decision Trees
#
# ## 1. Problem Overview
# Decision Trees are powerful, non-linear, and highly interpretable. We will build trees and visualize their rules.
#
# ## 2. Dataset Exploration
# Exploring a mixed categorical/numerical dataset.
#
# ## 3. Data Preprocessing
# No scaling needed! Just handle missing values and encode categoricals.
#
# ## 4. From Scratch Implementation
# Building a basic CART tree calculating Gini Impurity recursively.
#
# ## 5. NumPy Implementation
# Speeding up the threshold search.
#
# ## 6. Scikit-Learn Workflow
# Using `DecisionTreeClassifier` and `DecisionTreeRegressor`.
#
# ## 7. Visualization Lab
# Plotting the actual tree structure using `plot_tree`.
#
# ## 8. Hyperparameter Experiments
# Tuning `max_depth` and `min_samples_split` to prevent massive overfitting.
#
# ## 9. Failure Cases
# Demonstrating instability: change one row of data and watch the whole tree structure change.
#
# ## 10. Real Dataset Case Study
# Medical diagnosis prediction.
#
# ## 11. Mini Challenges
# Implement post-pruning (Cost Complexity Pruning).
#
# ## 12. Solutions
# Reveal solutions here.
#
# ## 13. Key Takeaways
# Trees are great for interpretability but prone to high variance.
#
# ## 14. Further Practice
# Move on to Random Forests to solve the high variance problem.

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# model = DecisionTreeClassifier(max_depth=3)
# model.fit(X_train, y_train)
# plt.figure(figsize=(12,8))
# plot_tree(model, filled=True)
# plt.show()
