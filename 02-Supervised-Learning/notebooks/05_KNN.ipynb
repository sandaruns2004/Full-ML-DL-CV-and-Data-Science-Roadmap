# %% [markdown]
# # K-Nearest Neighbors (KNN)
#
# ## 1. Problem Overview
# KNN is an instance-based learning algorithm. We will use it to predict labels based on geographical or spatial similarity.
#
# ## 2. Dataset Exploration
# Visualizing clusters in a 2D dataset.
#
# ## 3. Data Preprocessing
# CRITICAL: Scaling is absolutely mandatory for KNN to work properly.
#
# ## 4. From Scratch Implementation
# Computing Euclidean distance manually across loops.
#
# ## 5. NumPy Implementation
# Using `np.linalg.norm` and `np.argsort` for much faster predictions.
#
# ## 6. Scikit-Learn Workflow
# Using `KNeighborsClassifier`.
#
# ## 7. Visualization Lab
# Plotting the Voronoi-like decision boundaries.
#
# ## 8. Hyperparameter Experiments
# Testing k=1 (overfitting) vs k=100 (underfitting).
#
# ## 9. Failure Cases
# Curse of Dimensionality: adding 50 random noise features destroys accuracy.
#
# ## 10. Real Dataset Case Study
# Imputing missing values using KNNImputer.
#
# ## 11. Mini Challenges
# Try changing the distance metric to Manhattan.
#
# ## 12. Solutions
# Reveal solutions here.
#
# ## 13. Key Takeaways
# KNN is simple but scales terribly with dataset size and dimensions.
#
# ## 14. Further Practice
# Build a simple Collaborative Filtering recommender.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)
# model = KNeighborsClassifier(n_neighbors=5)
# model.fit(X_scaled, y)
