# %% [markdown]
# # Support Vector Machines (SVM)
#
# ## 1. Problem Overview
# SVMs find the maximum margin hyperplane. We will test both Linear and Non-Linear kernels.
#
# ## 2. Dataset Exploration
# Looking at overlapping vs perfectly separable data.
#
# ## 3. Data Preprocessing
# Scaling is strictly required to maximize geometric margins properly.
#
# ## 4. From Scratch Implementation
# Implementing a basic Hard-Margin SVM using gradient descent on the Hinge Loss.
#
# ## 5. NumPy Implementation
# Vectorizing Hinge Loss.
#
# ## 6. Scikit-Learn Workflow
# Using `SVC` and `LinearSVC`.
#
# ## 7. Visualization Lab
# Plotting the margin, the street, and circling the Support Vectors.
#
# ## 8. Hyperparameter Experiments
# Grid Searching C (Regularization) and Gamma (RBF influence).
#
# ## 9. Failure Cases
# SVM on massive datasets (>100k rows) stalling out.
#
# ## 10. Real Dataset Case Study
# Image classification (e.g., Eigenfaces).
#
# ## 11. Mini Challenges
# Implement polynomial features manually, then show how the `poly` kernel does it implicitly.
#
# ## 12. Solutions
# Reveal solutions here.
#
# ## 13. Key Takeaways
# The Kernel Trick is magic for non-linear data.
#
# ## 14. Further Practice
# Apply SVM to text classification.

# %%
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# model = make_pipeline(StandardScaler(), SVC(kernel='rbf', C=1.0, gamma='scale'))
# model.fit(X_train, y_train)
