# %% [markdown]
# # 💳 Credit Risk Modeling
# Focusing on precision/recall trade-offs and handling imbalanced datasets when predicting loan defaults.

# %%
import torch
import torch.nn as nn
from sklearn.metrics import precision_recall_curve
print('Credit Risk Modeling Notebook Initialized.')
