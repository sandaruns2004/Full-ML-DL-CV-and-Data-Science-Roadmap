# %% [markdown]
# # Notebook Title
# ## Theory
# Theory goes here.
# ## Mathematics
# $E = mc^2$
# ## Visualizations
# Visuals will be plotted here.
# ## Exercises
# 1. Do this.
# ## Solutions
# Solution goes here.

# %%
print('Hello Data Science')
