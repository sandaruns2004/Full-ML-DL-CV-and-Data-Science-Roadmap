# %% [markdown]
# # 📧 Spam Detection System
# Using Bag of Words / TF-IDF followed by a Feed-Forward Neural Network to classify spam.

# %%
import torch
import torch.nn as nn
print('Spam Detection Training Notebook Initialized.')
